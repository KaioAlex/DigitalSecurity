# %%
import pandas as pd
import numpy as np
import pyod
np.set_printoptions(precision=3)

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from pyod.models.knn import KNN

# %%
i = 0
for chunk in pd.read_csv('C:/Users/andre/Desktop/ddos-datasets/ddos_balanced/final_dataset.csv',sep=',',header=0, chunksize=10**4):
    if (i == 0):
        attacks = chunk
        newData = chunk
    else:
        normal = newData
        newData = chunk
    i = i+1
# Out:
# C:\Users\andre\Anaconda3\envs\security\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\andre\Anaconda3\envs\security\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
normal
# Out:
#           Unnamed: 0                                   Flow ID  \
# 12780000     3204326       172.31.0.2-172.31.65.84-53-53935-17
# 12780001     7526961  172.31.65.46-185.222.209.10-3389-55867-6
# 12780002     4455366      172.31.0.2-172.31.67.100-53-54573-17
# 12780003     2577153    172.31.64.81-68.67.178.252-52629-443-6
# 12780004      624265   172.31.64.126-216.58.198.78-52677-443-6
# ...              ...                                       ...
# 12789995     1939999      172.31.0.2-172.31.64.104-53-58136-17
# 12789996     3848442    172.31.66.50-71.252.199.2-3389-61274-6
# 12789997     3345150      172.31.0.2-172.31.66.105-53-59615-17
# 12789998     5423392                     8.0.6.4-8.6.0.1-0-0-0
# 12789999     6465795      172.31.65.77-52.84.2.252-51138-443-6
#
#                   Src IP  Src Port         Dst IP  Dst Port  Protocol  \
# 12780000    172.31.65.84     53935     172.31.0.2        53        17
# ...

# %%
attacks
# Out:
#       Unnamed: 0                                Flow ID         Src IP  \
# 0            624   192.168.4.118-203.73.24.75-4504-80-6  192.168.4.118
# 1            625   192.168.4.118-203.73.24.75-4504-80-6  192.168.4.118
# 2            626   192.168.4.118-203.73.24.75-4505-80-6  192.168.4.118
# 3            627   192.168.4.118-203.73.24.75-4505-80-6  192.168.4.118
# 4            628   192.168.4.118-203.73.24.75-4506-80-6  192.168.4.118
# ...          ...                                    ...            ...
# 9995       50142  192.168.56.1-67.220.214.50-37111-80-6   192.168.56.1
# 9996       50143  192.168.56.1-67.220.214.50-37116-80-6   192.168.56.1
# 9997       50144   192.168.4.120-203.73.24.75-3842-80-6  192.168.4.120
# 9998       50145   192.168.4.120-203.73.24.75-3842-80-6  192.168.4.120
# 9999       50146  192.168.56.1-67.220.214.50-37112-80-6   192.168.56.1
#
#       Src Port         Dst IP  Dst Port  Protocol               Timestamp  \
# ...

# %%
trainigSet = pd.concat([attacks, normal])
trainigSet
# Out:
#           Unnamed: 0                                 Flow ID         Src IP  \
# 0                624    192.168.4.118-203.73.24.75-4504-80-6  192.168.4.118
# 1                625    192.168.4.118-203.73.24.75-4504-80-6  192.168.4.118
# 2                626    192.168.4.118-203.73.24.75-4505-80-6  192.168.4.118
# 3                627    192.168.4.118-203.73.24.75-4505-80-6  192.168.4.118
# 4                628    192.168.4.118-203.73.24.75-4506-80-6  192.168.4.118
# ...              ...                                     ...            ...
# 12789995     1939999    172.31.0.2-172.31.64.104-53-58136-17  172.31.64.104
# 12789996     3848442  172.31.66.50-71.252.199.2-3389-61274-6   71.252.199.2
# 12789997     3345150    172.31.0.2-172.31.66.105-53-59615-17  172.31.66.105
# 12789998     5423392                   8.0.6.4-8.6.0.1-0-0-0        8.6.0.1
# 12789999     6465795    172.31.65.77-52.84.2.252-51138-443-6    52.84.2.252
#
# ...

# %%
trainigSet.to_csv(r'C:\Users\Andre\Desktop\trainig_set.csv', index = None, header=True)
